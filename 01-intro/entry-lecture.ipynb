# %%
from google import genai
import os

# %%
api_key = os.getenv("GEMINI_API_KEY") #key saved as a secret
client = genai.Client(api_key=api_key)

response = client.models.generate_content(
    model="gemini-2.0-flash",
    contents="How do I enroll in the course"
)

print(response.text)
# Out:
# To enroll in a course, you'll generally need to follow these steps, though the exact process can vary slightly depending on where the course is hosted:
#
# **General Steps:**
#
# 1.  **Find the Course:**
#     *   **Identify the platform or institution offering the course.**  Common platforms include:
#         *   **Online Learning Platforms:** Coursera, edX, Udemy, Skillshare, LinkedIn Learning, Udacity, Khan Academy, FutureLearn.
#         *   **University Websites:** Many universities offer online courses through their own websites.
#         *   **Company Websites:** Some companies offer training related to their products or services.
#         *   **Independent Instructors:**  Sometimes you'll find courses listed on personal websites or via email lists.
#     *   **Use search terms** on the platform or on Google.  For example: `"Python programming course Coursera"` or `"Data science certification edX"`.
#
# 2.  **Navigate to the Course Page:**
#     *   Once you find the course you want, click on its title or link to go to the specific course page.
#
# 3.  **Review the Course Details:**
#     *   Carefully read the course description, syllabus, instructor information, prerequisites (if any), required materials, cost (if any), and start/end dates.  Make sure it's a good fit for you.
#
# 4.  **Look for an "Enroll," "Register," "Join," "Sign Up," or "Start Learning" Button:**  This button is usually prominently displayed on the course page.
#
# 5.  **Create an Account or Log In:**
#     *   If you don't already have an account on the platform, you'll need to create one. This typically involves providing your email address, creating a password, and sometimes providing other basic information.
#     *   If you already have an account, log in with your credentials.
#
# 6.  **Payment (if required):**
#     *   Many online courses are free, but some require payment.
#     *   If payment is required, you'll be prompted to enter your payment information (credit card, PayPal, etc.).  Be sure to check for any available discounts or financial aid options.
#
# 7.  **Confirm Enrollment:**
#     *   After payment (if applicable), you'll typically receive a confirmation email and be redirected to the course dashboard or learning environment.
#
# 8.  **Start Learning!**
#     *   Explore the course materials, introduce yourself in the discussion forums (if available), and begin working through the lessons.
#
# **Specific Examples for Popular Platforms:**
#
# *   **Coursera/edX:**
#     *   Create an account or log in.
#     *   Click the "Enroll" button.
#     *   Choose an enrollment option (audit, certificate, degree). Auditing is often free but doesn't provide a certificate.
#     *   Follow the payment prompts if you choose a certificate or degree option.
#
# *   **Udemy/Skillshare:**
#     *   Create an account or log in.
#     *   Click the "Enroll Now" or "Start Free Trial" button.
#     *   Follow the payment prompts (if required after a free trial).
#
# *   **Khan Academy:**
#     *   Create an account or log in.
#     *   Click "Start Course."  Khan Academy courses are generally free.
#
# *   **University Websites:**
#     *   The enrollment process for university courses varies greatly.  You may need to apply to the university as a non-degree student, or the course might be offered through a partner platform (like Coursera or edX). Consult the university's website or the course description for specific instructions.
#
# **Troubleshooting Tips:**
#
# *   **Check the course FAQs:** Most platforms have a frequently asked questions (FAQ) section that addresses common enrollment issues.
# *   **Contact Support:** If you're having trouble enrolling, contact the platform's customer support.  They can usually help you resolve any technical issues.
# *   **Read the Fine Print:** Pay attention to any terms and conditions related to enrollment, payment, refunds, or course access.
# *   **Verify Your Email:** Make sure you're using the correct email address and that you've verified your email account if required.
#
# **To give you more tailored advice, please tell me:**
#
# *   **Where is this course offered?**  (e.g., Coursera, Udemy, a specific university, etc.)
# *   **What is the exact name of the course?**  (So I can look it up and provide specific instructions).
# *   **What problems are you experiencing during the enrollment process?**
#
# I can then give you more precise guidance.

# %%
import os
print(os.environ.get("GEMINI_API"))
# Out:
# None

# %%
dir(response)
# Out:
# ['__abstractmethods__',
#  '__annotations__',
#  '__class__',
#  '__class_getitem__',
#  '__class_vars__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__fields__',
#  '__fields_set__',
#  '__format__',
#  '__ge__',
#  '__get_pydantic_core_schema__',
#  '__get_pydantic_json_schema__',
#  '__getattr__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__pretty__',
#  '__private_attributes__',
#  '__pydantic_complete__',
#  '__pydantic_computed_fields__',
#  '__pydantic_core_schema__',
#  '__pydantic_custom_init__',
#  '__pydantic_decorators__',
#  '__pydantic_extra__',
#  '__pydantic_fields__',
#  '__pydantic_fields_set__',
#  '__pydantic_generic_metadata__',
#  '__pydantic_init_subclass__',
#  '__pydantic_parent_namespace__',
#  '__pydantic_post_init__',
#  '__pydantic_private__',
#  '__pydantic_root_model__',
#  '__pydantic_serializer__',
#  '__pydantic_setattr_handlers__',
#  '__pydantic_validator__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__replace__',
#  '__repr__',
#  '__repr_args__',
#  '__repr_name__',
#  '__repr_recursion__',
#  '__repr_str__',
#  '__rich_repr__',
#  '__setattr__',
#  '__setstate__',
#  '__signature__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_calculate_keys',
#  '_copy_and_set_values',
#  '_from_response',
#  '_get_text',
#  '_get_value',
#  '_iter',
#  '_setattr_handler',
#  'automatic_function_calling_history',
#  'candidates',
#  'code_execution_result',
#  'construct',
#  'copy',
#  'create_time',
#  'dict',
#  'executable_code',
#  'from_orm',
#  'function_calls',
#  'json',
#  'model_computed_fields',
#  'model_config',
#  'model_construct',
#  'model_copy',
#  'model_dump',
#  'model_dump_json',
#  'model_extra',
#  'model_fields',
#  'model_fields_set',
#  'model_json_schema',
#  'model_parametrized_name',
#  'model_post_init',
#  'model_rebuild',
#  'model_validate',
#  'model_validate_json',
#  'model_validate_strings',
#  'model_version',
#  'parse_file',
#  'parse_obj',
#  'parse_raw',
#  'parsed',
#  'prompt_feedback',
#  'response_id',
#  'schema',
#  'schema_json',
#  'text',
#  'to_json_dict',
#  'update_forward_refs',
#  'usage_metadata',
#  'validate']

# %%
print(response.prompt_feedback)
print(response.candidates)
# Out:
# None
# [Candidate(content=Content(parts=[Part(video_metadata=None, thought=None, inline_data=None, file_data=None, thought_signature=None, code_execution_result=None, executable_code=None, function_call=None, function_response=None, text='To enroll in a course, you\'ll need to know the following:\n\n1.  **Where is the course being offered?** Is it on a specific platform like Coursera, edX, Udemy, Skillshare, FutureLearn, a university\'s website, or a private company\'s site? The enrollment process will vary depending on the platform.\n\n2.  **What is the course title and/or code?** You\'ll need this to find the specific course you want to enroll in.\n\nOnce you have this information, here are the general steps you\'ll likely need to follow:\n\n**General Enrollment Steps (Platform Dependent):**\n\n1.  **Find the Course:**\n    *   **If you know the specific platform:** Go to the platform\'s website (e.g., Coursera.org, Udemy.com).\n    *   **If you don\'t know the platform:** Search on Google or your preferred search engine for "[Course Title] enrollment" or "[Platform Name] [Course Title]".\n\n2.  **Search or Browse:**\n    *   Use the platform\'s search bar and enter the course title or keywords.\n    *   Alternatively, browse the platform\'s course catalog, often categorized by subject area.\n\n3.  **Find the Course Page:** Click on the course listing to go to the course\'s dedicated page.\n\n4.  **Review Course Details:** Carefully read the course description, syllabus, instructor information, prerequisites, cost (if any), and any reviews from previous students.  Make sure it\'s the right course for you.\n\n5.  **Enroll/Register/Join Now Button:** Look for a button or link that says something like:\n    *   "Enroll"\n    *   "Register"\n    *   "Join Now"\n    *   "Sign Up"\n    *   "Add to Cart" (if there\'s a fee)\n\n6.  **Create an Account or Log In:**\n    *   If you don\'t already have an account on the platform, you\'ll need to create one. You\'ll typically need to provide your name, email address, and create a password.\n    *   If you already have an account, log in.\n\n7.  **Payment (If Applicable):**\n    *   If the course is not free, you\'ll be prompted to enter your payment information (credit card, debit card, PayPal, etc.).\n    *   Some platforms offer payment plans or financial aid; look for those options if needed.\n    *   Make sure you understand the refund policy.\n\n8.  **Confirmation:**\n    *   After enrolling, you should receive a confirmation email.\n    *   The course should now be accessible from your account dashboard on the platform.\n\n**Specific Enrollment Tips for Popular Platforms:**\n\n*   **Coursera:** Offers individual courses, Specializations (a series of related courses), and Degrees.  Look for the "Enroll for Free" option (for auditing a course without a certificate) or the option to pay for a certificate.\n*   **edX:** Similar to Coursera, offering individual courses, programs, and degrees.  Also offers free auditing options.\n*   **Udemy:** Known for a wide range of courses, often with promotional pricing.  Payment is typically required.\n*   **Skillshare:** Focuses on creative skills.  Often offers a subscription model.\n*   **FutureLearn:**  Offers courses from universities around the world.  Some courses are free, others require payment for full access and a certificate.\n\n**Important Considerations:**\n\n*   **Prerequisites:** Check if the course has any prerequisites (knowledge or skills you should have before taking the course).\n*   **Time Commitment:** Consider the estimated time commitment per week to ensure you have enough time to dedicate to the course.\n*   **Deadlines:** Be aware of any deadlines for enrollment or assignments.\n*   **Technical Requirements:** Check if you need any specific software or hardware to participate in the course.\n*   **Refund Policy:** Understand the platform\'s refund policy in case you need to withdraw from the course.\n* **Contact Information:** ...
